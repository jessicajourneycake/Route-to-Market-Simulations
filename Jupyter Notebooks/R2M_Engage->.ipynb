# %%
from openpyxl import Workbook
from openpyxl import load_workbook
import pandas as pd
import numpy as np
import os
import sys
import copy
import json
import sys

# %%
#Outputs all of the Stages, Counts, & Countries (Ex. Engage->Qualify)
if __name__ == "__main__":

    output_df = pd.DataFrame()

   

    directory = os.getcwd() + "/data"
    files = []
    for i in sorted(os.listdir(directory)):
        if os.path.isfile(os.path.join(directory,i)) and ('Product_Pipe' in i) and ('~' not in i):
            files.append(i)
    print(files)

 
#     if put in two excel sheets in commandline
#     if(len(sys.argv)>1):
#         #files = [sys.argv[1], sys.argv[2], sys.argv[3]]
#         files = sys.argv[1:]
#     else:
#         files = sorted(os.listdir(directory))
    

#     print(files)

    

    #first sheet we do value counts
    #prev = first sheet dataframe
    filename = files[0]
    

    f = os.path.join(directory, filename)
    print(f)
    df_prev = pd.read_excel(f, sheet_name='Sheet1')
    df_prev = pd.DataFrame(df_prev, columns=['Opp No', 'Sales Stage Name', 'Country', 'Opportunity Source', 'LIO Channel', 'Sector'])
    df_prev = df_prev.drop_duplicates(subset=["Opp No"], keep="last")
   

    filename = filename.split(".")[0][-5:]
 

    for i in range(1, len(files)):
        filename = files[i]
        f = os.path.join(directory, filename)
        df_current = pd.read_excel(f, sheet_name='Sheet1')
        df_current = pd.DataFrame(df_current, columns=['Opp No', 'Sales Stage Name', 'Country', 'Opportunity Source', 'LIO Channel', 'Sector'])
        print(df_current.head(3))
        df_current = df_current.drop_duplicates(subset=["Opp No"], keep="last")
        temp = df_current["Sales Stage Name"].value_counts()
        
        df_current = df_current.rename(columns= {'Opp No': "Opp No Cur", 'Sales Stage Name': "Sales Stage Name Cur", 'Country': "Country Cur", 'Opportunity Source': "Opp Source Cur", 'LIO Channel': "LIO Channel Cur", 'Sector': "Sector Cur"})
        df_compare = pd.merge(df_prev, df_current, how = "outer", left_on=df_prev["Opp No"], right_on = df_current["Opp No Cur"])

        df_compare = df_compare.fillna(0)
        df_compare.to_excel("test.xlsx")
        df_temp = pd.read_excel('engage.xlsx')
        temp2 = pd.DataFrame(df_temp)
        temp2.to_excel('temp2.xlsx')
        L = []
      
    
        newOpp_list = pd.DataFrame(columns=['Sales Stage Name'])

        #outputName = "compare" + str(i) + ".xlsx"
        #df_compare.to_excel(outputName)


        for index, row in df_compare.iterrows():

            Opp_No_prev = row["Opp No"]
            Opp_No_cur = row["Opp No Cur"]
            Country = row["Country Cur"]
            Country_prev = row["Country"]
            Opp_Source_prev = row["Opportunity Source"]
            Sector_prev = row["Sector"]
            LIO_Channel_prev = row["LIO Channel"]
            Opp_Source = row["Opp Source Cur"]
            Sector = row["Sector Cur"]
            LIO_Channel = row["LIO Channel Cur"]
            

            Sales_Stage_Name_prev = row["Sales Stage Name"]
            Sales_Stage_Name_cur = row["Sales Stage Name Cur"]

           
            if(Sales_Stage_Name_prev == "Engage" and Sales_Stage_Name_cur==0):
                #loss
                key1 = "Loss"
                key2 = "Engage->Loss"
                file = filename.split(".")[0][-5:]
                dat= [{'Date': file, 'Changes': key2, 'Changes_Cond': key1, 'Location': Country_prev, 'Source': Opp_Source_prev, 'Owner': LIO_Channel_prev, 'Sector': Sector_prev, 'Count': '1'}]
                dd = pd.DataFrame(dat)
                L.append(dd)
             
        
        
                
                
            elif(Sales_Stage_Name_prev == "Engage" and Sales_Stage_Name_cur!=0):
                key1 = Sales_Stage_Name_cur
                key2 = "Engage->" + Sales_Stage_Name_cur
                file = filename.split(".")[0][-5:]
                dat= [{'Date': file, 'Changes': key2, 'Changes_Cond': key1, 'Location': Country, 'Source': Opp_Source, 'Owner': LIO_Channel, 'Sector': Sector, 'Count': '1'}]
                dd = pd.DataFrame(dat)
                L.append(dd)
                    
                    
                
       #outside of loop
        df = pd.concat(L)
        df_temp = pd.read_excel('engage.xlsx', index_col=[0])
        df_temp = pd.DataFrame(df_temp)
        frames = [df_temp, df]
        df_output = pd.concat(frames, ignore_index=True)
        df_output.to_excel('engage.xlsx')
        df_current = df_current.rename(columns= {'Opp No Cur': "Opp No", 'Sales Stage Name Cur': "Sales Stage Name", 'Country Cur': "Country", 'Opp Source Cur': "Opportunity Source", 'LIO Channel Cur': "LIO Channel", 'Sector Cur': "Sector"})
        df_prev = df_current
# Out:
# ['Product_Pipe_09-27.xlsx', 'Product_Pipe_10-04.xlsx', 'Product_Pipe_10-11.xlsx', 'Product_Pipe_10-18.xlsx', 'Product_Pipe_10-25.xlsx', 'Product_Pipe_11-01.xlsx']
# /Users/Jessica.Journeycake@ibm.com/Desktop/R2M_UI/data/Product_Pipe_09-27.xlsx
#    Opp No Sales Stage Name        Country Opportunity Source  LIO Channel  \
# 0       1           Engage  United States        Field Sales  Field Sales
# 1       2           Engage  United States        Field Sales  Field Sales
# 2       3           Engage  United States        Field Sales  Field Sales
#
#                Sector
# 0  Energy & Utilities
# 1  Energy & Utilities
# 2  Energy & Utilities
# [    Date         Changes Changes_Cond       Location       Source  \
# 0  10-04  Engage->Engage       Engage  United States  Field Sales
#
#          Owner              Sector Count
# 0  Field Sales  Energy & Utilities     1  ,     Date         Changes Changes_Cond       Location       Source  \
# 0  10-04  Engage->Engage       Engage  United States  Field Sales
#
#          Owner              Sector Count
# 0  Field Sales  Energy & Utilities     1  ,     Date         Changes Changes_Cond       Location       Source  \
# 0  10-04  Engage->Engage       Engage  United States  Field Sales
#
#          Owner              Sector Count
# 0  Field Sales  Energy & Utilities     1  ,     Date          Changes Changes_Cond       Location       Source  \
# 0  10-04  Engage->Qualify      Qualify  United States  Field Sales
#
#          Owner              Sector Count
# 0  Field Sales  Energy & Utilities     1  ,     Date          Changes Changes_Cond       Location       Source  \
# 0  10-04  Engage->Qualify      Qualify  United States  Field Sales
#
#          Owner              Sector Count
# 0  Field Sales  Energy & Utilities     1  ,     Date          Changes Changes_Cond       Location       Source  \
# 0  10-04  Engage->Qualify      Qualify  United States  Field Sales
#
#          Owner                 Sector Count
# 0  Field Sales  Media & Entertainment     1  ,     Date          Changes Changes_Cond       Location       Source  \
# 0  10-04  Engage->Qualify      Qualify  United States  Field Sales
#
#          Owner                 Sector Count
# 0  Field Sales  Media & Entertainment     1  ,     Date         Changes Changes_Cond       Location       Source  \
# 0  10-04  Engage->Engage       Engage  United States  Field Sales
#
#          Owner              Sector Count
# 0  Field Sales  Energy & Utilities     1  ,     Date         Changes Changes_Cond       Location            Source  \
# 0  10-04  Engage->Engage       Engage  United States  Business Partner
#
#               Owner                   Sector Count
# 0  Business Partner  Travel & Transportation     1  ,     Date         Changes Changes_Cond       Location            Source  \
# 0  10-04  Engage->Engage       Engage  United States  Business Partner
#
#               Owner      Sector Count
# 0  Business Partner  Automotive     1  ,     Date         Changes Changes_Cond       Location            Source  \
# 0  10-04  Engage->Engage       Engage  United States  Business Partner
#
#               Owner      Sector Count
# 0  Business Partner  Automotive     1  ,     Date         Changes Changes_Cond   Location            Source  \
# 0  10-04  Engage->Design       Design  Australia  Business Partner
#
#               Owner                             Sector Count
# 0  Business Partner  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond   Location            Source  \
# 0  10-04  Engage->Engage       Engage  Australia  Business Partner
#
#               Owner                             Sector Count
# 0  Business Partner  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond   Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage  Australia  Field Sales  Field Sales
#
#                   Sector Count
# 0  Chemicals & Petroleum     1  ,     Date          Changes Changes_Cond   Location       Source        Owner  \
# 0  10-04  Engage->Qualify      Qualify  Australia  Field Sales  Field Sales
#
#                   Sector Count
# 0  Chemicals & Petroleum     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage  Belgium  Field Sales  Field Sales
#
#               Sector Count
# 0  Consumer Products     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage  Belgium  Field Sales  Field Sales
#
#               Sector Count
# 0  Consumer Products     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Engage       Engage  Belgium  Digital Client Rep
#
#                 Owner               Sector Count
# 0  Digital Client Rep  Industrial Products     1  ,     Date          Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Qualify      Qualify  Belgium  Digital Client Rep
#
#                 Owner               Sector Count
# 0  Digital Client Rep  Industrial Products     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                               Sector Count
# 0  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                Sector Count
# 0  Telecommunications     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Qualify      Qualify   Brazil  Field Sales  Field Sales
#
#                Sector Count
# 0  Telecommunications     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Qualify      Qualify   Brazil  Field Sales  Field Sales
#
#                Sector Count
# 0  Telecommunications     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                Sector Count
# 0  Telecommunications     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                 Sector Count
# 0  Industrial Products     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                 Sector Count
# 0  Industrial Products     1  ,     Date          Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Qualify      Qualify   Canada  Digital Client Rep
#
#                 Owner              Sector Count
# 0  Digital Client Rep  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Design       Design   Canada  Digital Client Rep
#
#                 Owner              Sector Count
# 0  Digital Client Rep  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Engage       Engage   Canada  Digital Client Rep
#
#                 Owner              Sector Count
# 0  Digital Client Rep  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Design       Design   Canada  Digital Client Rep
#
#                 Owner              Sector Count
# 0  Digital Client Rep  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Engage       Engage   Canada  Digital Client Rep
#
#                 Owner                 Sector Count
# 0  Digital Client Rep  Chemicals & Petroleum     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Engage       Engage   Canada  Digital Client Rep
#
#                 Owner                 Sector Count
# 0  Digital Client Rep  Chemicals & Petroleum     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage   Canada  Field Sales  Field Sales
#
#        Sector Count
# 0  Automotive     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage   Canada  Field Sales  Field Sales
#
#        Sector Count
# 0  Automotive     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Qualify      Qualify    China  Field Sales  Field Sales
#
#               Sector Count
# 0  Computer Services     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Qualify      Qualify    China  Field Sales  Field Sales
#
#               Sector Count
# 0  Computer Services     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage    China  Field Sales  Field Sales
#
#               Sector Count
# 0  Computer Services     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage    China  Field Sales  Field Sales
#
#               Sector Count
# 0  Computer Services     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Qualify      Qualify    China  Field Sales  Field Sales
#
#                 Sector Count
# 0  Industrial Products     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage    China  Field Sales  Field Sales
#
#                 Sector Count
# 0  Industrial Products     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage    China  Field Sales  Field Sales
#
#                 Sector Count
# 0  Industrial Products     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage  Croatia  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage  Croatia  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Design       Design  Croatia  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Design       Design  Croatia  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage  Croatia  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage  Croatia  Field Sales  Field Sales
#
#                               Sector Count
# 0  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage  Croatia  Field Sales  Field Sales
#
#                               Sector Count
# 0  Wholesale Distribution & Services     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Qualify      Qualify  Croatia  Field Sales  Field Sales
#
#                               Sector Count
# 0  Wholesale Distribution & Services     1  ,     Date          Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Qualify      Qualify  Denmark  Digital Client Rep
#
#                 Owner                 Sector Count
# 0  Digital Client Rep  Media & Entertainment     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Engage       Engage  Denmark  Digital Client Rep
#
#                 Owner                 Sector Count
# 0  Digital Client Rep  Media & Entertainment     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Engage       Engage  Denmark  Digital Client Rep
#
#                 Owner                 Sector Count
# 0  Digital Client Rep  Media & Entertainment     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Qualify      Qualify   France  Field Sales  Field Sales
#
#               Sector Count
# 0  Consumer Products     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Qualify      Qualify   France  Field Sales  Field Sales
#
#               Sector Count
# 0  Consumer Products     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Qualify      Qualify   France  Field Sales  Field Sales
#
#                               Sector Count
# 0  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage   France  Field Sales  Field Sales
#
#                               Sector Count
# 0  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond Location            Source  \
# 0  10-04  Engage->Engage       Engage   France  Business Partner
#
#               Owner                             Sector Count
# 0  Business Partner  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond Location            Source  \
# 0  10-04  Engage->Design       Design  Germany  Business Partner
#
#               Owner                   Sector Count
# 0  Business Partner  Travel & Transportation     1  ,     Date          Changes Changes_Cond Location            Source  \
# 0  10-04  Engage->Qualify      Qualify  Germany  Business Partner
#
#               Owner                   Sector Count
# 0  Business Partner  Travel & Transportation     1  ,     Date          Changes Changes_Cond Location            Source  \
# 0  10-04  Engage->Qualify      Qualify  Germany  Business Partner
#
#               Owner                   Sector Count
# 0  Business Partner  Travel & Transportation     1  ,     Date         Changes Changes_Cond Location            Source  \
# 0  10-04  Engage->Engage       Engage  Germany  Business Partner
#
#               Owner                   Sector Count
# 0  Business Partner  Travel & Transportation     1  ,     Date         Changes Changes_Cond Location            Source  \
# 0  10-04  Engage->Engage       Engage  Germany  Business Partner
#
#               Owner  Sector Count
# 0  Business Partner  Retail     1  ,     Date          Changes Changes_Cond Location            Source  \
# 0  10-04  Engage->Qualify      Qualify  Germany  Business Partner
#
#               Owner  Sector Count
# 0  Business Partner  Retail     1  ,     Date          Changes Changes_Cond Location            Source  \
# 0  10-04  Engage->Qualify      Qualify  Germany  Business Partner
#
#               Owner  Sector Count
# 0  Business Partner  Retail     1  ,     Date         Changes Changes_Cond Location            Source  \
# 0  10-04  Engage->Engage       Engage  Germany  Business Partner
#
#               Owner  Sector Count
# 0  Business Partner  Retail     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage  Germany  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage  Germany  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond        Location            Source  \
# 0  10-04  Engage->Engage       Engage  United Kingdom  Business Partner
#
#               Owner  Sector Count
# 0  Business Partner  Retail     1  ,     Date         Changes Changes_Cond        Location            Source  \
# 0  10-04  Engage->Engage       Engage  United Kingdom  Business Partner
#
#               Owner  Sector Count
# 0  Business Partner  Retail     1  ,     Date         Changes Changes_Cond        Location            Source  \
# 0  10-04  Engage->Design       Design  United Kingdom  Business Partner
#
#               Owner               Sector Count
# 0  Business Partner  Industrial Products     1  ,     Date          Changes Changes_Cond        Location            Source  \
# 0  10-04  Engage->Qualify      Qualify  United Kingdom  Business Partner
#
#               Owner             Sector Count
# 0  Business Partner  Computer Services     1  ,     Date         Changes Changes_Cond        Location            Source  \
# 0  10-04  Engage->Engage       Engage  United Kingdom  Business Partner
#
#               Owner             Sector Count
# 0  Business Partner  Computer Services     1  ,     Date          Changes Changes_Cond        Location              Source  \
# 0  10-04  Engage->Qualify      Qualify  United Kingdom  Digital Client Rep
#
#                 Owner             Sector Count
# 0  Digital Client Rep  Computer Services     1  ,     Date         Changes Changes_Cond        Location              Source  \
# 0  10-04  Engage->Engage       Engage  United Kingdom  Digital Client Rep
#
#                 Owner             Sector Count
# 0  Digital Client Rep  Consumer Products     1  ,     Date          Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Qualify      Qualify    Spain  Digital Client Rep
#
#                 Owner              Sector Count
# 0  Digital Client Rep  Telecommunications     1  ,     Date          Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Qualify      Qualify    Spain  Digital Client Rep
#
#                 Owner              Sector Count
# 0  Digital Client Rep  Telecommunications     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Engage       Engage    Spain  Digital Client Rep
#
#                 Owner              Sector Count
# 0  Digital Client Rep  Telecommunications     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Engage       Engage    Spain  Digital Client Rep
#
#                 Owner              Sector Count
# 0  Digital Client Rep  Telecommunications     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Qualify      Qualify    Spain  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage    Spain  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage    Spain  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage    Spain  Field Sales  Field Sales
#
#                   Sector Count
# 0  Media & Entertainment     1  ,     Date          Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Qualify      Qualify   Mexico  Digital Client Rep
#
#                 Owner                 Sector Count
# 0  Digital Client Rep  Media & Entertainment     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Design       Design   Mexico  Digital Client Rep
#
#                 Owner                 Sector Count
# 0  Digital Client Rep  Media & Entertainment     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Engage       Engage   Mexico  Digital Client Rep
#
#                 Owner                 Sector Count
# 0  Digital Client Rep  Media & Entertainment     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Engage       Engage   Greece  Digital Client Rep
#
#                 Owner                 Sector Count
# 0  Digital Client Rep  Media & Entertainment     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Engage       Engage   Greece  Digital Client Rep
#
#                 Owner                 Sector Count
# 0  Digital Client Rep  Media & Entertainment     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Qualify      Qualify    India  Field Sales  Field Sales
#
#                   Sector Count
# 0  Chemicals & Petroleum     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Qualify      Qualify    India  Field Sales  Field Sales
#
#                   Sector Count
# 0  Chemicals & Petroleum     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage    India  Field Sales  Field Sales
#
#                   Sector Count
# 0  Chemicals & Petroleum     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Design       Design    India  Field Sales  Field Sales
#
#                   Sector Count
# 0  Chemicals & Petroleum     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage    India  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage    India  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage    India  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Qualify      Qualify    India  Field Sales  Field Sales
#
#                 Sector Count
# 0  Industrial Products     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage    India  Field Sales  Field Sales
#
#                 Sector Count
# 0  Industrial Products     1  ,     Date         Changes Changes_Cond Location            Source  \
# 0  10-04  Engage->Engage       Engage    Japan  Business Partner
#
#               Owner      Sector Count
# 0  Business Partner  Automotive     1  ,     Date         Changes Changes_Cond Location            Source  \
# 0  10-04  Engage->Engage       Engage    Japan  Business Partner
#
#               Owner              Sector Count
# 0  Business Partner  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location            Source  \
# 0  10-04  Engage->Design       Design    Japan  Business Partner
#
#               Owner              Sector Count
# 0  Business Partner  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Engage       Engage    Japan  Digital Client Rep
#
#                 Owner              Sector Count
# 0  Digital Client Rep  Energy & Utilities     1  ,     Date          Changes Changes_Cond Location              Source  \
# 0  10-04  Engage->Qualify      Qualify    Japan  Digital Client Rep
#
#                 Owner                   Sector Count
# 0  Digital Client Rep  Travel & Transportation     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  10-04  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner  Sector Count
# 0  Digital Client Rep  Retail     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  10-04  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner  Sector Count
# 0  Digital Client Rep  Retail     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  10-04  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner  Sector Count
# 0  Digital Client Rep  Retail     1  ,     Date          Changes Changes_Cond       Location              Source  \
# 0  10-04  Engage->Qualify      Qualify  United States  Digital Client Rep
#
#                 Owner                   Sector Count
# 0  Digital Client Rep  Travel & Transportation     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  10-04  Engage->Design       Design  United States  Digital Client Rep
#
#                 Owner                   Sector Count
# 0  Digital Client Rep  Travel & Transportation     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  10-04  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner                   Sector Count
# 0  Digital Client Rep  Travel & Transportation     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  10-04  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner                   Sector Count
# 0  Digital Client Rep  Travel & Transportation     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  10-04  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner             Sector Count
# 0  Digital Client Rep  Consumer Products     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#    Sector Count
# 0  Retail     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Qualify      Qualify   Brazil  Field Sales  Field Sales
#
#    Sector Count
# 0  Retail     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Qualify      Qualify   Brazil  Field Sales  Field Sales
#
#    Sector Count
# 0  Retail     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                Sector Count
# 0  Telecommunications     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                Sector Count
# 0  Telecommunications     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                               Sector Count
# 0  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                               Sector Count
# 0  Wholesale Distribution & Services     1  ,     Date          Changes Changes_Cond   Location       Source        Owner  \
# 0  10-04  Engage->Qualify      Qualify  Australia  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond   Location       Source        Owner  \
# 0  10-04  Engage->Engage       Engage  Australia  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date          Changes Changes_Cond   Location       Source        Owner  \
# 0  10-04  Engage->Qualify      Qualify  Australia  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ]
#    Opp No Sales Stage Name        Country Opportunity Source  LIO Channel  \
# 0       1           Engage  United States        Field Sales  Field Sales
# 1       2          Qualify  United States        Field Sales  Field Sales
# 2       3          Qualify  United States        Field Sales  Field Sales
#
#                Sector
# 0  Energy & Utilities
# 1  Energy & Utilities
# 2  Energy & Utilities
# [    Date         Changes Changes_Cond       Location       Source  \
# 0  10-11  Engage->Engage       Engage  United States  Field Sales
#
#          Owner              Sector Count
# 0  Field Sales  Energy & Utilities     1  ,     Date          Changes Changes_Cond       Location       Source  \
# 0  10-11  Engage->Qualify      Qualify  United States  Field Sales
#
#          Owner              Sector Count
# 0  Field Sales  Energy & Utilities     1  ,     Date          Changes Changes_Cond       Location       Source  \
# 0  10-11  Engage->Qualify      Qualify  United States  Field Sales
#
#          Owner              Sector Count
# 0  Field Sales  Energy & Utilities     1  ,     Date         Changes Changes_Cond       Location       Source  \
# 0  10-11  Engage->Engage       Engage  United States  Field Sales
#
#          Owner              Sector Count
# 0  Field Sales  Energy & Utilities     1  ,     Date         Changes Changes_Cond       Location            Source  \
# 0  10-11  Engage->Engage       Engage  United States  Business Partner
#
#               Owner                   Sector Count
# 0  Business Partner  Travel & Transportation     1  ,     Date         Changes Changes_Cond       Location            Source  \
# 0  10-11  Engage->Engage       Engage  United States  Business Partner
#
#               Owner      Sector Count
# 0  Business Partner  Automotive     1  ,     Date         Changes Changes_Cond       Location            Source  \
# 0  10-11  Engage->Engage       Engage  United States  Business Partner
#
#               Owner      Sector Count
# 0  Business Partner  Automotive     1  ,     Date          Changes Changes_Cond   Location            Source  \
# 0  10-11  Engage->Qualify      Qualify  Australia  Business Partner
#
#               Owner                             Sector Count
# 0  Business Partner  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond   Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage  Australia  Field Sales  Field Sales
#
#                   Sector Count
# 0  Chemicals & Petroleum     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Qualify      Qualify  Belgium  Field Sales  Field Sales
#
#               Sector Count
# 0  Consumer Products     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage  Belgium  Field Sales  Field Sales
#
#               Sector Count
# 0  Consumer Products     1  ,     Date          Changes Changes_Cond Location              Source  \
# 0  10-11  Engage->Qualify      Qualify  Belgium  Digital Client Rep
#
#                 Owner               Sector Count
# 0  Digital Client Rep  Industrial Products     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                               Sector Count
# 0  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                Sector Count
# 0  Telecommunications     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                Sector Count
# 0  Telecommunications     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Qualify      Qualify   Brazil  Field Sales  Field Sales
#
#                 Sector Count
# 0  Industrial Products     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                 Sector Count
# 0  Industrial Products     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-11  Engage->Engage       Engage   Canada  Digital Client Rep
#
#                 Owner              Sector Count
# 0  Digital Client Rep  Energy & Utilities     1  ,     Date          Changes Changes_Cond Location              Source  \
# 0  10-11  Engage->Qualify      Qualify   Canada  Digital Client Rep
#
#                 Owner                 Sector Count
# 0  Digital Client Rep  Chemicals & Petroleum     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-11  Engage->Engage       Engage   Canada  Digital Client Rep
#
#                 Owner                 Sector Count
# 0  Digital Client Rep  Chemicals & Petroleum     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage   Canada  Field Sales  Field Sales
#
#        Sector Count
# 0  Automotive     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage   Canada  Field Sales  Field Sales
#
#        Sector Count
# 0  Automotive     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage    China  Field Sales  Field Sales
#
#               Sector Count
# 0  Computer Services     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage    China  Field Sales  Field Sales
#
#               Sector Count
# 0  Computer Services     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Qualify      Qualify    China  Field Sales  Field Sales
#
#                 Sector Count
# 0  Industrial Products     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Qualify      Qualify    China  Field Sales  Field Sales
#
#                 Sector Count
# 0  Industrial Products     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage  Croatia  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage  Croatia  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Qualify      Qualify  Croatia  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage  Croatia  Field Sales  Field Sales
#
#                               Sector Count
# 0  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage  Croatia  Field Sales  Field Sales
#
#                               Sector Count
# 0  Wholesale Distribution & Services     1  ,     Date          Changes Changes_Cond Location              Source  \
# 0  10-11  Engage->Qualify      Qualify  Denmark  Digital Client Rep
#
#                 Owner                 Sector Count
# 0  Digital Client Rep  Media & Entertainment     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-11  Engage->Engage       Engage  Denmark  Digital Client Rep
#
#                 Owner                 Sector Count
# 0  Digital Client Rep  Media & Entertainment     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage   France  Field Sales  Field Sales
#
#                               Sector Count
# 0  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond Location            Source  \
# 0  10-11  Engage->Engage       Engage   France  Business Partner
#
#               Owner                             Sector Count
# 0  Business Partner  Wholesale Distribution & Services     1  ,     Date          Changes Changes_Cond Location            Source  \
# 0  10-11  Engage->Qualify      Qualify  Germany  Business Partner
#
#               Owner                   Sector Count
# 0  Business Partner  Travel & Transportation     1  ,     Date         Changes Changes_Cond Location            Source  \
# 0  10-11  Engage->Engage       Engage  Germany  Business Partner
#
#               Owner  Sector Count
# 0  Business Partner  Retail     1  ,     Date         Changes Changes_Cond Location            Source  \
# 0  10-11  Engage->Engage       Engage  Germany  Business Partner
#
#               Owner  Sector Count
# 0  Business Partner  Retail     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Qualify      Qualify  Germany  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage  Germany  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond        Location            Source  \
# 0  10-11  Engage->Engage       Engage  United Kingdom  Business Partner
#
#               Owner  Sector Count
# 0  Business Partner  Retail     1  ,     Date          Changes Changes_Cond        Location            Source  \
# 0  10-11  Engage->Qualify      Qualify  United Kingdom  Business Partner
#
#               Owner  Sector Count
# 0  Business Partner  Retail     1  ,     Date         Changes Changes_Cond        Location            Source  \
# 0  10-11  Engage->Engage       Engage  United Kingdom  Business Partner
#
#               Owner             Sector Count
# 0  Business Partner  Computer Services     1  ,     Date         Changes Changes_Cond        Location              Source  \
# 0  10-11  Engage->Engage       Engage  United Kingdom  Digital Client Rep
#
#                 Owner             Sector Count
# 0  Digital Client Rep  Consumer Products     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-11  Engage->Engage       Engage    Spain  Digital Client Rep
#
#                 Owner              Sector Count
# 0  Digital Client Rep  Telecommunications     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-11  Engage->Engage       Engage    Spain  Digital Client Rep
#
#                 Owner              Sector Count
# 0  Digital Client Rep  Telecommunications     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage    Spain  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage    Spain  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage    Spain  Field Sales  Field Sales
#
#                   Sector Count
# 0  Media & Entertainment     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-11  Engage->Engage       Engage   Mexico  Digital Client Rep
#
#                 Owner                 Sector Count
# 0  Digital Client Rep  Media & Entertainment     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-11  Engage->Engage       Engage   Greece  Digital Client Rep
#
#                 Owner                 Sector Count
# 0  Digital Client Rep  Media & Entertainment     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-11  Engage->Engage       Engage   Greece  Digital Client Rep
#
#                 Owner                 Sector Count
# 0  Digital Client Rep  Media & Entertainment     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage    India  Field Sales  Field Sales
#
#                   Sector Count
# 0  Chemicals & Petroleum     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage    India  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage    India  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage    India  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage    India  Field Sales  Field Sales
#
#                 Sector Count
# 0  Industrial Products     1  ,     Date         Changes Changes_Cond Location            Source  \
# 0  10-11  Engage->Engage       Engage    Japan  Business Partner
#
#               Owner      Sector Count
# 0  Business Partner  Automotive     1  ,     Date         Changes Changes_Cond Location            Source  \
# 0  10-11  Engage->Engage       Engage    Japan  Business Partner
#
#               Owner              Sector Count
# 0  Business Partner  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location              Source  \
# 0  10-11  Engage->Engage       Engage    Japan  Digital Client Rep
#
#                 Owner              Sector Count
# 0  Digital Client Rep  Energy & Utilities     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  10-11  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner  Sector Count
# 0  Digital Client Rep  Retail     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  10-11  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner  Sector Count
# 0  Digital Client Rep  Retail     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  10-11  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner  Sector Count
# 0  Digital Client Rep  Retail     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  10-11  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner                   Sector Count
# 0  Digital Client Rep  Travel & Transportation     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  10-11  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner                   Sector Count
# 0  Digital Client Rep  Travel & Transportation     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  10-11  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner             Sector Count
# 0  Digital Client Rep  Consumer Products     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#    Sector Count
# 0  Retail     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                Sector Count
# 0  Telecommunications     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                Sector Count
# 0  Telecommunications     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                               Sector Count
# 0  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                               Sector Count
# 0  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond   Location       Source        Owner  \
# 0  10-11  Engage->Engage       Engage  Australia  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond       Location       Source  \
# 0  10-11  Engage->Engage       Engage  United States  Field Sales
#
#          Owner                             Sector Count
# 0  Field Sales  Wholesale Distribution & Services     1  ,     Date          Changes Changes_Cond       Location       Source  \
# 0  10-11  Engage->Qualify      Qualify  United States  Field Sales
#
#          Owner                             Sector Count
# 0  Field Sales  Wholesale Distribution & Services     1  ,     Date          Changes Changes_Cond       Location            Source  \
# 0  10-11  Engage->Qualify      Qualify  United States  Business Partner
#
#               Owner                             Sector Count
# 0  Business Partner  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond       Location            Source  \
# 0  10-11  Engage->Engage       Engage  United States  Business Partner
#
#               Owner                             Sector Count
# 0  Business Partner  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond   Location            Source  \
# 0  10-11  Engage->Engage       Engage  Australia  Business Partner
#
#               Owner                 Sector Count
# 0  Business Partner  Chemicals & Petroleum     1  ,     Date         Changes Changes_Cond   Location            Source  \
# 0  10-11  Engage->Engage       Engage  Australia  Business Partner
#
#               Owner                 Sector Count
# 0  Business Partner  Chemicals & Petroleum     1  ]
#    Opp No Sales Stage Name        Country Opportunity Source  LIO Channel  \
# 0       1          Qualify  United States        Field Sales  Field Sales
# 1       2          Qualify  United States        Field Sales  Field Sales
# 2       3          Qualify  United States        Field Sales  Field Sales
#
#                Sector
# 0  Energy & Utilities
# 1  Energy & Utilities
# 2  Energy & Utilities
# [    Date          Changes Changes_Cond       Location       Source  \
# 0  10-18  Engage->Qualify      Qualify  United States  Field Sales
#
#          Owner              Sector Count
# 0  Field Sales  Energy & Utilities     1  ,     Date          Changes Changes_Cond       Location       Source  \
# 0  10-18  Engage->Qualify      Qualify  United States  Field Sales
#
#          Owner              Sector Count
# 0  Field Sales  Energy & Utilities     1  ,     Date          Changes Changes_Cond       Location            Source  \
# 0  10-18  Engage->Qualify      Qualify  United States  Business Partner
#
#               Owner                   Sector Count
# 0  Business Partner  Travel & Transportation     1  ,     Date         Changes Changes_Cond       Location            Source  \
# 0  10-18  Engage->Engage       Engage  United States  Business Partner
#
#               Owner      Sector Count
# 0  Business Partner  Automotive     1  ,     Date         Changes Changes_Cond       Location            Source  \
# ...
# 0  10-25  Engage->Engage       Engage    Spain  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  10-25  Engage->Qualify      Qualify    Spain  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-25  Engage->Engage       Engage    Spain  Field Sales  Field Sales
#
#                   Sector Count
# 0  Media & Entertainment     1  ,     Date          Changes Changes_Cond Location              Source  \
# 0  10-25  Engage->Qualify      Qualify   Greece  Digital Client Rep
#
#                 Owner                 Sector Count
# 0  Digital Client Rep  Media & Entertainment     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-25  Engage->Engage       Engage    India  Field Sales  Field Sales
#
#                   Sector Count
# 0  Chemicals & Petroleum     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-25  Engage->Engage       Engage    India  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-25  Engage->Design       Design    India  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-25  Engage->Engage       Engage    India  Field Sales  Field Sales
#
#                 Sector Count
# 0  Industrial Products     1  ,     Date         Changes Changes_Cond Location            Source  \
# 0  10-25  Engage->Engage       Engage    Japan  Business Partner
#
#               Owner      Sector Count
# 0  Business Partner  Automotive     1  ,     Date         Changes Changes_Cond Location            Source  \
# 0  10-25  Engage->Engage       Engage    Japan  Business Partner
#
#               Owner              Sector Count
# 0  Business Partner  Energy & Utilities     1  ,     Date          Changes Changes_Cond Location              Source  \
# 0  10-25  Engage->Qualify      Qualify    Japan  Digital Client Rep
#
#                 Owner              Sector Count
# 0  Digital Client Rep  Energy & Utilities     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  10-25  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner  Sector Count
# 0  Digital Client Rep  Retail     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  10-25  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner  Sector Count
# 0  Digital Client Rep  Retail     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  10-25  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner                   Sector Count
# 0  Digital Client Rep  Travel & Transportation     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  10-25  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner                   Sector Count
# 0  Digital Client Rep  Travel & Transportation     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  10-25  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner             Sector Count
# 0  Digital Client Rep  Consumer Products     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-25  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#    Sector Count
# 0  Retail     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-25  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                Sector Count
# 0  Telecommunications     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-25  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                               Sector Count
# 0  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-25  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                               Sector Count
# 0  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond       Location       Source  \
# 0  10-25  Engage->Engage       Engage  United States  Field Sales
#
#          Owner                             Sector Count
# 0  Field Sales  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond       Location            Source  \
# 0  10-25  Engage->Engage       Engage  United States  Business Partner
#
#               Owner                             Sector Count
# 0  Business Partner  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond   Location            Source  \
# 0  10-25  Engage->Engage       Engage  Australia  Business Partner
#
#               Owner                 Sector Count
# 0  Business Partner  Chemicals & Petroleum     1  ,     Date          Changes Changes_Cond   Location            Source  \
# 0  10-25  Engage->Qualify      Qualify  Australia  Business Partner
#
#               Owner                 Sector Count
# 0  Business Partner  Chemicals & Petroleum     1  ,     Date         Changes Changes_Cond Location            Source  \
# 0  10-25  Engage->Engage       Engage  Germany  Business Partner
#
#               Owner      Sector Count
# 0  Business Partner  Automotive     1  ,     Date         Changes Changes_Cond Location            Source  \
# 0  10-25  Engage->Engage       Engage  Germany  Business Partner
#
#               Owner      Sector Count
# 0  Business Partner  Automotive     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-25  Engage->Engage       Engage  Germany  Field Sales  Field Sales
#
#    Sector Count
# 0  Retail     1  ,     Date         Changes Changes_Cond        Location       Source  \
# 0  10-25  Engage->Engage       Engage  United Kingdom  Field Sales
#
#          Owner              Sector Count
# 0  Field Sales  Energy & Utilities     1  ,     Date         Changes Changes_Cond       Location       Source  \
# 0  10-25  Engage->Engage       Engage  United States  Field Sales
#
#          Owner              Sector Count
# 0  Field Sales  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-25  Engage->Engage       Engage  Belgium  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  10-25  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ]
#    Opp No Sales Stage Name        Country Opportunity Source  LIO Channel  \
# 0       1          Qualify  United States        Field Sales  Field Sales
# 1       2           Design  United States        Field Sales  Field Sales
# 2       3           Design  United States        Field Sales  Field Sales
#
#                Sector
# 0  Energy & Utilities
# 1  Energy & Utilities
# 2  Energy & Utilities
# [    Date         Changes Changes_Cond       Location            Source  \
# 0  11-01  Engage->Engage       Engage  United States  Business Partner
#
#               Owner      Sector Count
# 0  Business Partner  Automotive     1  ,     Date         Changes Changes_Cond       Location            Source  \
# 0  11-01  Engage->Engage       Engage  United States  Business Partner
#
#               Owner      Sector Count
# 0  Business Partner  Automotive     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  11-01  Engage->Qualify      Qualify  Belgium  Field Sales  Field Sales
#
#               Sector Count
# 0  Consumer Products     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  11-01  Engage->Qualify      Qualify   Brazil  Field Sales  Field Sales
#
#                 Sector Count
# 0  Industrial Products     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  11-01  Engage->Qualify      Qualify  Croatia  Field Sales  Field Sales
#
#                               Sector Count
# 0  Wholesale Distribution & Services     1  ,     Date          Changes Changes_Cond Location            Source  \
# 0  11-01  Engage->Qualify      Qualify  Germany  Business Partner
#
#               Owner  Sector Count
# 0  Business Partner  Retail     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  11-01  Engage->Qualify      Qualify    Spain  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  11-01  Engage->Engage       Engage    Spain  Field Sales  Field Sales
#
#                   Sector Count
# 0  Media & Entertainment     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  11-01  Engage->Engage       Engage    India  Field Sales  Field Sales
#
#                   Sector Count
# 0  Chemicals & Petroleum     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  11-01  Engage->Engage       Engage    India  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  11-01  Engage->Design       Design    India  Field Sales  Field Sales
#
#                 Sector Count
# 0  Industrial Products     1  ,     Date          Changes Changes_Cond Location            Source  \
# 0  11-01  Engage->Qualify      Qualify    Japan  Business Partner
#
#               Owner      Sector Count
# 0  Business Partner  Automotive     1  ,     Date          Changes Changes_Cond Location            Source  \
# 0  11-01  Engage->Qualify      Qualify    Japan  Business Partner
#
#               Owner              Sector Count
# 0  Business Partner  Energy & Utilities     1  ,     Date          Changes Changes_Cond       Location              Source  \
# 0  11-01  Engage->Qualify      Qualify  United States  Digital Client Rep
#
#                 Owner  Sector Count
# 0  Digital Client Rep  Retail     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  11-01  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner  Sector Count
# 0  Digital Client Rep  Retail     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  11-01  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner                   Sector Count
# 0  Digital Client Rep  Travel & Transportation     1  ,     Date          Changes Changes_Cond       Location              Source  \
# 0  11-01  Engage->Qualify      Qualify  United States  Digital Client Rep
#
#                 Owner                   Sector Count
# 0  Digital Client Rep  Travel & Transportation     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  11-01  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner             Sector Count
# 0  Digital Client Rep  Consumer Products     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  11-01  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#    Sector Count
# 0  Retail     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  11-01  Engage->Design       Design   Brazil  Field Sales  Field Sales
#
#                Sector Count
# 0  Telecommunications     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  11-01  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                               Sector Count
# 0  Wholesale Distribution & Services     1  ,     Date          Changes Changes_Cond Location       Source        Owner  \
# 0  11-01  Engage->Qualify      Qualify   Brazil  Field Sales  Field Sales
#
#                               Sector Count
# 0  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond       Location       Source  \
# 0  11-01  Engage->Engage       Engage  United States  Field Sales
#
#          Owner                             Sector Count
# 0  Field Sales  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond       Location            Source  \
# 0  11-01  Engage->Engage       Engage  United States  Business Partner
#
#               Owner                             Sector Count
# 0  Business Partner  Wholesale Distribution & Services     1  ,     Date         Changes Changes_Cond   Location            Source  \
# 0  11-01  Engage->Engage       Engage  Australia  Business Partner
#
#               Owner                 Sector Count
# 0  Business Partner  Chemicals & Petroleum     1  ,     Date         Changes Changes_Cond Location            Source  \
# 0  11-01  Engage->Engage       Engage  Germany  Business Partner
#
#               Owner      Sector Count
# 0  Business Partner  Automotive     1  ,     Date         Changes Changes_Cond Location            Source  \
# 0  11-01  Engage->Engage       Engage  Germany  Business Partner
#
#               Owner      Sector Count
# 0  Business Partner  Automotive     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  11-01  Engage->Engage       Engage  Germany  Field Sales  Field Sales
#
#    Sector Count
# 0  Retail     1  ,     Date         Changes Changes_Cond        Location       Source  \
# 0  11-01  Engage->Engage       Engage  United Kingdom  Field Sales
#
#          Owner              Sector Count
# 0  Field Sales  Energy & Utilities     1  ,     Date         Changes Changes_Cond       Location       Source  \
# 0  11-01  Engage->Engage       Engage  United States  Field Sales
#
#          Owner              Sector Count
# 0  Field Sales  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  11-01  Engage->Engage       Engage  Belgium  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  11-01  Engage->Engage       Engage   Brazil  Field Sales  Field Sales
#
#                Sector Count
# 0  Energy & Utilities     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  11-01  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner                   Sector Count
# 0  Digital Client Rep  Travel & Transportation     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  11-01  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner                 Sector Count
# 0  Digital Client Rep  Media & Entertainment     1  ,     Date         Changes Changes_Cond       Location              Source  \
# 0  11-01  Engage->Engage       Engage  United States  Digital Client Rep
#
#                 Owner              Sector Count
# 0  Digital Client Rep  Telecommunications     1  ,     Date         Changes Changes_Cond Location       Source        Owner  \
# 0  11-01  Engage->Engage       Engage    China  Field Sales  Field Sales
#
#               Sector Count
# 0  Computer Services     1  ,     Date         Changes Changes_Cond     Location       Source        Owner  \
# 0  11-01  Engage->Engage       Engage  New Zealand  Field Sales  Field Sales
#
#    Sector Count
# 0  Retail     1  ]

# %%
#Engage Stats
df2 = pd.read_excel('engage.xlsx', index_col=False)
df2 = pd.DataFrame(df2)
print(df2.head(5))
df2 = df2.drop(columns=['Unnamed: 0', 'Source', 'Owner', 'Sector', 'Date'])

df2 = df2["Changes"].value_counts()
df2 = pd.DataFrame(df2)
df2 = df2.rename(columns={"Changes": "Count"})
df2.to_excel('engage_stats.xlsx')
df2 = pd.read_excel('engage_stats.xlsx', index_col=False)
df2 = pd.DataFrame(df2)
df2 = df2.rename(columns={'Unnamed: 0': "Changes"})
df2.to_excel('engage_stats.xlsx')
# Out:
#    Unnamed: 0 Changes_Cond       Location       Source        Owner  \
# 0           0       Engage  United States  Field Sales  Field Sales
# 1           1       Engage  United States  Field Sales  Field Sales
# 2           2       Engage  United States  Field Sales  Field Sales
# 3           3      Qualify  United States  Field Sales  Field Sales
# 4           4      Qualify  United States  Field Sales  Field Sales
#
#                Sector  Count   Date          Changes
# 0  Energy & Utilities      1  10-04   Engage->Engage
# 1  Energy & Utilities      1  10-04   Engage->Engage
# 2  Energy & Utilities      1  10-04   Engage->Engage
# 3  Energy & Utilities      1  10-04  Engage->Qualify
# 4  Energy & Utilities      1  10-04  Engage->Qualify

# %%
#Engage by Location
df2 = pd.read_excel('engage.xlsx', index_col=False)
df2 = pd.DataFrame(df2)
df2 = df2.drop(columns=['Unnamed: 0', 'Source', 'Owner', 'Sector', 'Date'])
# df2.Location = df2.Location.str.strip()
df2 = df2.groupby(['Location', 'Changes'], as_index=False)["Count"].sum()
df2.to_excel('engage_location.xlsx')

# %%
#Engage by Owner
df2 = pd.read_excel('engage.xlsx', index_col=False)
df2 = pd.DataFrame(df2)
df2 = df2.drop(columns=['Unnamed: 0', 'Location', 'Source', 'Sector', 'Date'])
df2.Owner = df2.Owner.str.strip()
df2 = df2.groupby(['Owner', 'Changes'], as_index=False)["Count"].sum()
df2.to_excel('engage_owner.xlsx')

# %%
#Engage by Sector
df2 = pd.read_excel('engage.xlsx', index_col=False)
df2 = pd.DataFrame(df2)
df2 = df2.drop(columns=['Unnamed: 0', 'Location', 'Source', 'Owner', 'Date'])
df2.Sector = df2.Sector.str.strip()
df2 = df2.groupby(['Sector', 'Changes'], as_index=False)["Count"].sum()
df2.to_excel('engage_sector.xlsx')
